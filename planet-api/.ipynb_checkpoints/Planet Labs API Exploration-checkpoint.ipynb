# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
# %matplotlib inline

from PIL import Image

from IPython.display import clear_output

# these magics ensure that external modules that are modified are also automatically reloaded
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
myPlanetKey = "664df19c4dcd42b3b7d14acd5b9936b4"
outputPath  = "/home/ubuntu/data/prop39/images-planet/"

locations = [(-122.0983579, 37.6584694), (-122.232073, 37.751768)]

# %% [markdown]
# ### Using Planet's Python client

# %%
from planet import api
client = api.Client(api_key=myPlanetKey)

# %%
print "Total data available from Planet by constellation:"
for sceneType in ["landsat", "ortho"]:
    scenes = client.get_scenes_list(scene_type=sceneType)
    print "%7s: %d"%(sceneType, scenes.get()['count'])
# Out:
# Total data available from Planet by constellation:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# landsat: 706909
#   ortho: 44551

# %%
filters = {'cloud_cover.estimated.lt': 1}
# scenes = client.get_scenes_list(intersects=wkt, limit=None, **filters)
# scenes = client.get_scenes_list(scene_type='ortho')
# scenes = client.get_scenes_list(scene_type='landsat')
wkt = 'POINT(37.65 -122.09)'
scenes = client.get_scenes_list(scene_type='landsat', intersection=wkt, limit=None, **filters)
geojson= scenes.get()

print "%d scenes"%geojson['count']
# Out:
# 116439 scenes

# %%
geojson['features'][0]
# Out:
# {u'geometry': {u'coordinates': [[[43.9128970451521, -69.7471202234119],
#     [48.4591200981543, -70.4960588854333],
#     [46.1946502954664, -72.0777394112879],
#     [41.3706981605894, -71.270499479547],
#     [43.9128970451521, -69.7471202234119]]],
#   u'type': u'Polygon'},
#  u'id': u'LC81441102016256LGN00',
#  u'properties': {u'acquired': u'2016-09-12T05:34:38.904664+00:00',
#   u'camera': {u'bit_depth': 12},
#   u'cloud_cover': {u'estimated': 0.47},
#   u'data': {u'products': {u'band_1': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_1'},
#     u'band_10': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_10'},
#     u'band_11': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_11'},
#     u'band_2': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_2'},
#     u'band_3': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_3'},
#     u'band_4': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_4'},
#     u'band_5': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_5'},
#     u'band_6': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_6'},
#     u'band_7': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_7'},
#     u'band_8': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_8'},
#     u'band_9': {u'full': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/full?product=band_9'}}},
#   u'image_statistics': {u'gsd': 30.0},
#   u'landsat': {u'data_type': u'L1GT', u'path': 144, u'row': 110},
#   u'links': {u'self': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00',
#    u'thumbnail': u'https://api.planet.com/v0/scenes/landsat/LC81441102016256LGN00/thumb'},
#   u'provider': u'landsat',
#   u'published': u'2016-09-12T05:34:38.904664+00:00',
#   u'sat': {u'alt': 720.0, u'id': u'LANDSAT_8', u'off_nadir': -0.0},
#   u'sun': {u'altitude': 8.1607222, u'azimuth': 50.91929334}},
#  u'type': u'Feature'}

# %%
scene_ids = [scene['id'] for scene in scenes.items_iter(5)]
print len(scene_ids)
print scene_ids
# Out:
# 5
# [u'LC81441102016256LGN00', u'LC81441092016256LGN00', u'LC81281122016256LGN00', u'LC81281112016256LGN00', u'LC81280302016256LGN00']

# %%
metadata_body = client.get_scene_metadata(scene_id='LC81441102016256LGN00')
metadata = metadata_body.get()
print metadata['properties']['sat']
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# ---------------------------------------------------------------------------
# MissingResource                           Traceback (most recent call last)
# <ipython-input-13-c160fca916d8> in <module>()
# ----> 1 metadata_body = client.get_scene_metadata(scene_id='LC81441102016256LGN00')
#       2 metadata = metadata_body.get()
#       3 print metadata['properties']['sat']
#
# /usr/local/lib/python2.7/dist-packages/planet/api/client.pyc in get_scene_metadata(self, scene_id, scene_type)
#     134         """
#     135         # todo: accept/return multiple scenes
# --> 136         return self._get('scenes/%s/%s' % (scene_type, scene_id)).get_body()
#     137
#     138     def fetch_scene_geotiffs(self, scene_ids, scene_type='ortho',
#
# /usr/local/lib/python2.7/dist-packages/planet/api/models.pyc in get_body(self)
#      43         '''
#      44         if self._body is None:
# ---> 45             resp = self._dispatcher._dispatch(self.request)
#      46             self._body = self._create_body(resp)
#      47         return self._body
#
# /usr/local/lib/python2.7/dist-packages/planet/api/dispatch.pyc in _dispatch(self, request, callback)
#      76     def _dispatch(self, request, callback=None):
#      77         response = self._dispatch_async(request, callback).result()
# ---> 78         check_status(response)
#      79         return response
#      80
#
# /usr/local/lib/python2.7/dist-packages/planet/api/utils.pyc in check_status(response)
#     120
#     121     if exception:
# --> 122         raise exception(response.text)
#     123
#     124     raise exceptions.APIException('%s: %s' % (status, response.text))
#
# MissingResource: <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server.  If you entered the URL manually please check your spelling and try again.</p>

# %%
callback = api.write_to_file(directory='/home/ubuntu/data/prop39/images-planet/')
callbacks = client.fetch_scene_geotiffs(scene_ids, callback=callback)
for cb in callbacks:
    body = cb.await()
    print 'downloaded', body.name, 'size=%s bytes' % len(body)
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# downloaded 20160818_200414_0c19_visual.tif size=22974209 bytes
# downloaded 20160818_200413_0c19_visual.tif size=22719121 bytes
# downloaded 20160818_200411_0c19_visual.tif size=24215248 bytes
# downloaded 20160818_200411_1_0c19_visual.tif size=26094672 bytes
# downloaded 20160818_200410_0c19_visual.tif size=29528372 bytes

# %% [markdown]
# ### Using raw Python

# %%
from shapely.geometry import Point

# %%
# construct request for Planet API

# define AOI

# (longitude, latitude)
sf_nw = locations[0]
sf_se = locations[1]
sf_ne = (sf_se[0], sf_nw[1])
sf_sw = (sf_nw[0], sf_se[1])

# Using WKT

from shapely.geometry import Polygon
from shapely.wkt import dumps as wkt_dumps

poly = Polygon([sf_nw, sf_ne, sf_se, sf_sw, sf_nw])
intersects = wkt_dumps(poly)

# Or, using GeoJSON

import geojson

poly = geojson.Polygon([[sf_nw, sf_ne, sf_se, sf_sw, sf_nw]])
intersects = geojson.dumps(poly)

# Back to shared code between WKT and GeoJSON

filters = {
    # Your filters here, for example:
    # Cloud cover less than 1%
    "cloud_cover.estimated.lte": 1,
    "intersects": intersects,
    'page.acquired.gt': "2012-01-01T00:00:00"
}

# ortho, landsat, rapideye
url = "https://api.planet.com/v0/scenes/ortho/"

# %%
sf_nw
# Out:
# (-122.0983579, 37.6584694)

# %%
import geojson
geojson.

# %%
# send request, get response
r = requests.get(url, params=filters, auth=(myPlanetKey, ''))
r.raise_for_status()
data = r.json()
scenes_data = data["features"]
scene = scenes_data[0]
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
len(scenes_data), data['count']
# Out:
# (32, 32)

# %%
data['links']
# Out:
# {u'first': u'https://api.planet.com/v0/scenes/ortho/?page.acquired.gt=2012-01-01T00%3A00%3A00&cloud_cover.estimated.lte=1&intersects=%7B%22type%22%3A+%22Polygon%22%2C+%22coordinates%22%3A+%5B%5B%5B-122.0983579%2C+37.6584694%5D%2C+%5B-122.232073%2C+37.6584694%5D%2C+%5B-122.232073%2C+37.751768%5D%2C+%5B-122.0983579%2C+37.751768%5D%2C+%5B-122.0983579%2C+37.6584694%5D%5D%5D%7D',
#  u'next': u'https://api.planet.com/v0/scenes/ortho/?page.acquired.gt=2012-01-01T00%3A00%3A00&cloud_cover.estimated.lte=1&intersects=%7B%22type%22%3A+%22Polygon%22%2C+%22coordinates%22%3A+%5B%5B%5B-122.0983579%2C+37.6584694%5D%2C+%5B-122.232073%2C+37.6584694%5D%2C+%5B-122.232073%2C+37.751768%5D%2C+%5B-122.0983579%2C+37.751768%5D%2C+%5B-122.0983579%2C+37.6584694%5D%5D%5D%7D&_page.acquired.lt=2015-08-30T00%3A06%3A52.166234%2B00%3A00',
#  u'prev': u'https://api.planet.com/v0/scenes/ortho/?page.acquired.gt=2012-01-01T00%3A00%3A00&cloud_cover.estimated.lte=1&intersects=%7B%22type%22%3A+%22Polygon%22%2C+%22coordinates%22%3A+%5B%5B%5B-122.0983579%2C+37.6584694%5D%2C+%5B-122.232073%2C+37.6584694%5D%2C+%5B-122.232073%2C+37.751768%5D%2C+%5B-122.0983579%2C+37.751768%5D%2C+%5B-122.0983579%2C+37.6584694%5D%5D%5D%7D&_page.acquired.gt=2016-08-19T19%3A21%3A01.766624%2B00%3A00',
#  u'self': u'https://api.planet.com/v0/scenes/ortho/?page.acquired.gt=2012-01-01T00%3A00%3A00&cloud_cover.estimated.lte=1&intersects=%7B%22type%22%3A+%22Polygon%22%2C+%22coordinates%22%3A+%5B%5B%5B-122.0983579%2C+37.6584694%5D%2C+%5B-122.232073%2C+37.6584694%5D%2C+%5B-122.232073%2C+37.751768%5D%2C+%5B-122.0983579%2C+37.751768%5D%2C+%5B-122.0983579%2C+37.6584694%5D%5D%5D%7D'}

# %%
scene
# Out:
# {u'geometry': {u'coordinates': [[[-122.08691324136005, 37.7542865650151],
#     [-121.92752486593407, 37.61968183669242],
#     [-121.98046746517628, 37.57961540632538],
#     [-122.14042562012484, 37.71438114053217],
#     [-122.08691324136005, 37.7542865650151]]],
#   u'type': u'Polygon'},
#  u'id': u'20160819_192101_0c24',
#  u'properties': {u'acquired': u'2016-08-19T19:21:01.766624+00:00',
#   u'area': 280.70153045961,
#   u'camera': {u'bit_depth': 12,
#    u'color_mode': u'RGB',
#    u'exposure_time': 868,
#    u'gain': 0,
#    u'tdi_pulses': 12},
#   u'cloud_cover': {u'estimated': 0.11275897837700662},
#   u'data': {u'products': {u'analytic': {u'full': u'https://api.planet.com/v0/scenes/ortho/20160819_192101_0c24/full?product=analytic'},
#     u'visual': {u'full': u'https://api.planet.com/v0/scenes/ortho/20160819_192101_0c24/full?product=visual'}}},
#   u'image_statistics': {u'gsd': 3.11099747365,
#    u'image_quality': u'target',
#    u'snr': 72.92927378343724},
#   u'links': {u'full': u'https://api.planet.com/v0/scenes/ortho/20160819_192101_0c24/full',
#    u'self': u'https://api.planet.com/v0/scenes/ortho/20160819_192101_0c24',
#    u'square_thumbnail': u'https://api.planet.com/v0/scenes/ortho/20160819_192101_0c24/square-thumb',
#    u'thumbnail': u'https://api.planet.com/v0/scenes/ortho/20160819_192101_0c24/thumb'},
#   u'provider': u'ortho',
#   u'published': u'2016-09-02T19:21:01.766624+00:00',
#   u'sat': {u'alt': 394.826325961,
#    u'id': u'0c24',
#    u'lat': 37.6397263403,
#    u'lng': -122.094700552,
#    u'off_nadir': 0.4393100753428158},
#   u'strip_id': 1471634448.880017,
#   u'sun': {u'altitude': 62.368738594569216,
#    u'azimuth': 152.4505462747366,
#    u'local_time_of_day': 11.210631074311113}},
#  u'type': u'Feature'}

# %%
# extract fields of interest from scene metadata
timeAcquired = scene["properties"]['acquired']
cloudCoverEst= scene["properties"]['cloud_cover']['estimated']
nrScenes     = data['count']

# links to actual scene data
full_link  = scene["properties"]["links"]['self']
thumb_link = scene["properties"]["links"]['thumbnail']
anal_link  = scene["properties"]['data']['products']['analytic']['full']

# links to next scene
next_url = data["links"].get("next", None)

# %%
# obtain current scene data

import urllib
import cStringIO 

web_sock   = urllib.urlopen(anal_link)
imgdata    = cStringIO.StringIO(web_sock.read()) # constructs a StringIO holding the image
imgstr     = imgdata.getvalue()

# %%
r = requests.get(anal_link, stream=True, auth=(myPlanetKey, ''))
if 'content-disposition' in r.headers:
    local_filename = r.headers['content-disposition'] \
        .split("filename=")[-1].strip("'\"")
else:
    local_filename = '.'.join(url.split('/')[-2:])
    print local_filename

imgdata = "".join([chunk for chunk in r.iter_content(chunk_size=1024)])
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
imgdata==imgstr
# Out:
# True

# %%
# convert image data to numpy array

import numpy as np
import cv2

nparr = np.fromstring(imgstr, np.uint8)
imgarr = cv2.imdecode(nparr, cv2.IMREAD_LOAD_GDAL)
print imgarr.shape
# Out:
# (6428, 6296, 4)

# %%
imgarr.sum((0,1))
# Out:
# array([  9320459096,  10153264836,   7487132476, 964552584015], dtype=uint64)

# %%
# save data to disc
with open("tmp.tiff", "wb") as output:
    output.write(imgstr)

# from libtiff import TIFF
# tiff = TIFF.open('tmp2.tiff', mode='w')
# tiff.write_image(imgdata.getvalue())
# tiff.close()

# %%
plt.figure(figsize=(8,8))
plt.imshow(imgarr[:,:,1:])

# %%
import requests
import urllib3   

next_url = "https://api.planet.com/v0/scenes/ortho/?" \
    + urllib.urlencode(filters)   

while next_url:
    # Note: you don't have to pass the filters in again here,
    # here, they will always be included in data.links.next
    r = requests.get(next_url, auth=(key, ''))
    r.raise_for_status()
    data = r.json()
    scenes_data = data["features"]
    # do something with scenes_data
    break
    next_url = data["links"].get("next", None)

# %% [markdown]
# # Test own planetlabs API client

# %%
import planetlabs as pl

# %%
plClient = pl.PlanetLabsAPI(key=myPlanetKey, dataType="scenes", provider="ortho")

# %%
scenesData = plClient.get_scenes_metadata(limit=100)
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# There are 46298 relevant scenes. Retrieved data for the first 100.

# %%
len(scenesData)
# Out:
# 10

# %%
scenesData[0]
# Out:
# {u'geometry': {u'coordinates': [[[-114.46738303163714, 32.805320809812926],
#     [-114.18780803852805, 32.75324394080898],
#     [-114.20704115825377, 32.678755648719],
#     [-114.48694224986545, 32.73064016156677],
#     [-114.46738303163714, 32.805320809812926]]],
#   u'type': u'Polygon'},
#  u'id': u'20160902_172807_0e30',
#  u'properties': {u'acquired': u'2016-09-02T17:28:07.853968+00:00',
#   u'area': 478.66443764092253,
#   u'camera': {u'bit_depth': 12,
#    u'color_mode': u'RGB',
#    u'exposure_time': 1087,
#    u'gain': 0,
#    u'tdi_pulses': 8},
#   u'cloud_cover': {u'estimated': 0.002051010082947353},
#   u'data': {u'products': {u'analytic': {u'full': u'https://api.planet.com/v0/scenes/ortho/20160902_172807_0e30/full?product=analytic'},
#     u'visual': {u'full': u'https://api.planet.com/v0/scenes/ortho/20160902_172807_0e30/full?product=visual'}}},
#   u'image_statistics': {u'gsd': 4.08249864091,
#    u'image_quality': u'target',
#    u'snr': 91.91085179763009},
#   u'links': {u'full': u'https://api.planet.com/v0/scenes/ortho/20160902_172807_0e30/full',
#    u'self': u'https://api.planet.com/v0/scenes/ortho/20160902_172807_0e30',
#    u'square_thumbnail': u'https://api.planet.com/v0/scenes/ortho/20160902_172807_0e30/square-thumb',
#    u'thumbnail': u'https://api.planet.com/v0/scenes/ortho/20160902_172807_0e30/thumb'},
#   u'provider': u'ortho',
#   u'published': u'2016-09-16T17:28:07.853968+00:00',
#   u'sat': {u'alt': 516.773788348,
#    u'id': u'0e30',
#    u'lat': 32.5942310395,
#    u'lng': -114.075749291,
#    u'off_nadir': 3.0502477365563694},
#   u'strip_id': 1472836355.485995,
#   u'sun': {u'altitude': 51.267833627128006,
#    u'azimuth': 123.16549549128165,
#    u'local_time_of_day': 9.863561158377776}},
#  u'type': u'Feature'}

# %%
link = scenesData[0]['properties']['data']['products']['analytic']['full']

img = plClient.get_image_data_from_url(anal_link)
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning

# %%
img.shape
# Out:
# (6428, 6296, 4)

# %%
plt.figure(figsize=(8,8))
plt.imshow(img[:,:,1:])

# %%
plt.hist(img[:,:,3].flatten())
# Out:
# (array([ 25752559.,         0.,         0.,         0.,         0.,
#                 0.,         0.,         0.,         0.,  14718129.]),
#  array([     0. ,   6553.5,  13107. ,  19660.5,  26214. ,  32767.5,
#          39321. ,  45874.5,  52428. ,  58981.5,  65535. ]),
#  <a list of 10 Patch objects>)

# %%
plClient.download_image_from_url(anal_link)
# Out:
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/ssl_.py:90: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
# './/20160819_192101_0c24_analytic.tif'

# %%
from datetime import datetime, timedelta
import pytz

# %%
datetime(year=2014, month=8, day=1, tzinfo=pytz.utc).isoformat()
# Out:
# '2014-08-01T00:00:00+00:00'

# %%
datetime.now().date() - timedelta(days=365)
# Out:
# datetime.date(2015, 9, 17)
