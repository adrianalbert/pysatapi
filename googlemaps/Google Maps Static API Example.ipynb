# %%
import sys, os
import urllib2, httplib

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import numpy as np
import pandas as pd

from IPython.display import clear_output

# these magics ensure that external modules that are modified are also automatically reloaded
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../google-maps-api/")
import GoogleMaps as gmaps

# %%
loc = "San Francisco, CA"

# %% [markdown]
# Initialize client with Google API key

# %%
myAPIKey   = "AIzaSyAmgXPgd-Db8HD_juxtPf_4nricPBdcOrw"
gm = gmaps.GoogleMaps(key=myAPIKey)

# %% [markdown]
# Construct API call and obtain image

# %%
request = gm.construct_static_url(center=loc, zoom=10, maptype="satellite")
print request

img = gm.get_static_map_image(request)
# Out:
# http://maps.google.com/maps/api/staticmap?center=San+Francisco,+CA&zoom=10&key=AIzaSyAmgXPgd-Db8HD_juxtPf_4nricPBdcOrw&size=500x500&format=jpeg&maptype=satellite&sensor=false

# %%
img.shape
# Out:
# (500, 500, 3)

# %%
plt.figure(figsize=(7,7))
plt.imshow(img)
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1298: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=400:stretch=normal:size=medium. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %% [markdown]
# Save image to file

# %%
gm.get_static_map_image(request, filename="test.png")
# Out:
# 'test.png'
